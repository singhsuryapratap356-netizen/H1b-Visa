# %% [markdown]
# Importing libraries for data manipulation (Pandas, NumPy) and MySQL database connection

# %%
import pandas as pd
import numpy as np
import mysql.connector

# %% [markdown]
# Establishing connection to the MySQL database (h1b_visa)

# %%
conn = mysql.connector.connect(user = "root", password = "Root@123", database = "h1b_visa")

# %%
quary = "select * from h1b_data"

# %%
df = pd.read_sql(quary,conn)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14796\1170436564.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(quary,conn)

# %% [markdown]
# Displaying the first 5 rows of the dataset to quickly inspect the data

# %%
df.head()
# Out:
#           CASE_NUMBER CASE_STATUS RECEIVED_DATE DECISION_DATE  \
# 0  I-200-24366-578757   Withdrawn    31-12-2024    31-12-2024
# 1  I-200-24366-578499   Withdrawn    31-12-2024    31-12-2024
# 2  I-200-24366-578081   Withdrawn    31-12-2024    31-12-2024
# 3  I-200-24366-578384   Withdrawn    31-12-2024    31-12-2024
# 4  I-200-24366-578405   Withdrawn    31-12-2024    31-12-2024
#
#   ORIGINAL_CERT_DATE VISA_CLASS  \
# 0                          H-1B
# 1                          H-1B
# 2                          H-1B
# 3                          H-1B
# 4                          H-1B
#
#                                            JOB_TITLE    SOC_CODE  \
# 0                             Database Administrator  15-1242.00
# 1  Abdominal Radiologist Assistant Professor Clin...  29-1224.00
# 2                                    PROJECT MANAGER  15-1299.09
# 3                            Database Administrators  15-1242.00
# ...

# %% [markdown]
# Checking the number of rows and columns in the dataset

# %%
df.shape
# Out:
# (596550, 97)

# %% [markdown]
# Displaying the names of all columns in the dataset

# %%
df.columns
# Out:
# Index(['CASE_NUMBER', 'CASE_STATUS', 'RECEIVED_DATE', 'DECISION_DATE',
#        'ORIGINAL_CERT_DATE', 'VISA_CLASS', 'JOB_TITLE', 'SOC_CODE',
#        'SOC_TITLE', 'FULL_TIME_POSITION', 'BEGIN_DATE', 'END_DATE',
#        'TOTAL_WORKER_POSITIONS', 'NEW_EMPLOYMENT', 'CONTINUED_EMPLOYMENT',
#        'CHANGE_PREVIOUS_EMPLOYMENT', 'NEW_CONCURRENT_EMPLOYMENT',
#        'CHANGE_EMPLOYER', 'AMENDED_PETITION', 'EMPLOYER_NAME',
#        'TRADE_NAME_DBA', 'EMPLOYER_ADDRESS1', 'EMPLOYER_ADDRESS2',
#        'EMPLOYER_CITY', 'EMPLOYER_STATE', 'EMPLOYER_POSTAL_CODE',
#        'EMPLOYER_COUNTRY', 'EMPLOYER_PROVINCE', 'EMPLOYER_PHONE',
#        'EMPLOYER_PHONE_EXT', 'EMPLOYER_FEIN', 'NAICS_CODE',
#        'EMPLOYER_POC_LAST_NAME', 'EMPLOYER_POC_FIRST_NAME',
#        'EMPLOYER_POC_MIDDLE_NAME', 'EMPLOYER_POC_JOB_TITLE',
#        'EMPLOYER_POC_ADDRESS1', 'EMPLOYER_POC_ADDRESS2', 'EMPLOYER_POC_CITY',
#        'EMPLOYER_POC_STATE', 'EMPLOYER_POC_POSTAL_CODE',
# ...

# %% [markdown]
# Removing unnecessary employer contact and address etc columns to simplify the dataset

# %%
df = df.drop(columns=['EMPLOYER_ADDRESS1',
'EMPLOYER_ADDRESS2',
'EMPLOYER_CITY',
'EMPLOYER_POSTAL_CODE',
'EMPLOYER_PROVINCE',
'EMPLOYER_PHONE',
'EMPLOYER_PHONE_EXT',
'EMPLOYER_FEIN',
'EMPLOYER_POC_FIRST_NAME',
'EMPLOYER_POC_MIDDLE_NAME',
'EMPLOYER_POC_ADDRESS1',
'EMPLOYER_POC_ADDRESS2',
'EMPLOYER_POC_CITY',
'EMPLOYER_POC_STATE',
'EMPLOYER_POC_POSTAL_CODE',
'EMPLOYER_POC_PROVINCE',
'EMPLOYER_POC_PHONE',
'EMPLOYER_POC_PHONE_EXT',
'EMPLOYER_POC_EMAIL',
'EMPLOYER_POC_LAST_NAME'])

# %%
df = df.drop(columns=['AGENT_ATTORNEY_LAST_NAME',
'AGENT_ATTORNEY_FIRST_NAME',
'AGENT_ATTORNEY_MIDDLE_NAME',
'AGENT_ATTORNEY_ADDRESS1',
'AGENT_ATTORNEY_ADDRESS2',
'AGENT_ATTORNEY_CITY',
'AGENT_ATTORNEY_STATE',
'AGENT_ATTORNEY_POSTAL_CODE',
'AGENT_ATTORNEY_COUNTRY',
'AGENT_ATTORNEY_PROVINCE',
'AGENT_ATTORNEY_PHONE',
'AGENT_ATTORNEY_PHONE_EXT',
'AGENT_ATTORNEY_EMAIL_ADDRESS',
'LAWFIRM_NAME_BUSINESS_NAME',
'NAME_OF_HIGHEST_STATE_COURT',
'WORKSITE_ADDRESS1',
'WORKSITE_ADDRESS2',
'WORKSITE_POSTAL_CODE',
'SECONDARY_ENTITY',
'SECONDARY_ENTITY_BUSINESS_NAME',
'PW_TRACKING_NUMBER',
'PW_OES_YEAR',
'PW_OTHER_SOURCE',
'PW_OTHER_YEAR',
'PW_SURVEY_PUBLISHER',
'PW_SURVEY_NAME',
'TOTAL_WORKSITE_LOCATIONS'])

# %%
df = df.drop(columns=['AGREE_TO_LC_STATEMENT',
'WILLFUL_VIOLATOR',
'STATUTORY_BASIS',
'APPENDIX_A_ATTACHED',
'PUBLIC_DISCLOSURE',
'PREPARER_LAST_NAME',
'PREPARER_FIRST_NAME',
'PREPARER_MIDDLE_INITIAL',
'PREPARER_BUSINESS_NAME',
'PREPARER_EMAIL',
'ORIGINAL_CERT_DATE',
'BEGIN_DATE',
'END_DATE',
'CONTINUED_EMPLOYMENT',
'CHANGE_PREVIOUS_EMPLOYMENT',
'NEW_CONCURRENT_EMPLOYMENT',
'CHANGE_EMPLOYER',
'TRADE_NAME_DBA',
'EMPLOYER_COUNTRY',
'EMPLOYER_POC_COUNTRY',
'AGENT_REPRESENTING_EMPLOYER',
'STATE_OF_HIGHEST_COURT',
'SUPPORT_H1B'])

# %% [markdown]
# Displaying the remaining columns after removing unnecessary columns

# %%
df.columns
# Out:
# Index(['CASE_NUMBER', 'CASE_STATUS', 'RECEIVED_DATE', 'DECISION_DATE',
#        'VISA_CLASS', 'JOB_TITLE', 'SOC_CODE', 'SOC_TITLE',
#        'FULL_TIME_POSITION', 'TOTAL_WORKER_POSITIONS', 'NEW_EMPLOYMENT',
#        'AMENDED_PETITION', 'EMPLOYER_NAME', 'EMPLOYER_STATE', 'NAICS_CODE',
#        'EMPLOYER_POC_JOB_TITLE', 'WORKSITE_WORKERS', 'WORKSITE_CITY',
#        'WORKSITE_COUNTY', 'WORKSITE_STATE', 'WAGE_RATE_OF_PAY_FROM',
#        'WAGE_RATE_OF_PAY_TO', 'WAGE_UNIT_OF_PAY', 'PREVAILING_WAGE',
#        'PW_UNIT_OF_PAY', 'PW_WAGE_LEVEL', 'H-1B_DEPENDENT'],
#       dtype='object')

# %% [markdown]
# Checking the number of missing (null) values in each column

# %%
df.isnull().sum()
# Out:
# CASE_NUMBER                    0
# CASE_STATUS                    0
# RECEIVED_DATE             132131
# DECISION_DATE             132131
# VISA_CLASS                132131
# JOB_TITLE                 132131
# SOC_CODE                  132131
# SOC_TITLE                 132131
# FULL_TIME_POSITION        132131
# TOTAL_WORKER_POSITIONS    132131
# NEW_EMPLOYMENT            132131
# AMENDED_PETITION          132131
# EMPLOYER_NAME             132131
# EMPLOYER_STATE            132131
# NAICS_CODE                132131
# EMPLOYER_POC_JOB_TITLE    132131
# WORKSITE_WORKERS          132131
# WORKSITE_CITY             132131
# WORKSITE_COUNTY           132131
# WORKSITE_STATE            132131
# WAGE_RATE_OF_PAY_FROM     132131
# WAGE_RATE_OF_PAY_TO       132131
# WAGE_UNIT_OF_PAY          132131
# PREVAILING_WAGE           132131
# PW_UNIT_OF_PAY            132131
# PW_WAGE_LEVEL             132131
# H-1B_DEPENDENT            132131
# dtype: int64

# %% [markdown]
# Removing rows that contain missing (null) values from the dataset

# %%
df = df.dropna()

# %% [markdown]
# Rechecking the dataset to confirm that all missing (null) values have been removed

# %%
df.isnull().sum()
# Out:
# CASE_NUMBER               0
# CASE_STATUS               0
# RECEIVED_DATE             0
# DECISION_DATE             0
# VISA_CLASS                0
# JOB_TITLE                 0
# SOC_CODE                  0
# SOC_TITLE                 0
# FULL_TIME_POSITION        0
# TOTAL_WORKER_POSITIONS    0
# NEW_EMPLOYMENT            0
# AMENDED_PETITION          0
# EMPLOYER_NAME             0
# EMPLOYER_STATE            0
# NAICS_CODE                0
# EMPLOYER_POC_JOB_TITLE    0
# WORKSITE_WORKERS          0
# WORKSITE_CITY             0
# WORKSITE_COUNTY           0
# WORKSITE_STATE            0
# WAGE_RATE_OF_PAY_FROM     0
# WAGE_RATE_OF_PAY_TO       0
# WAGE_UNIT_OF_PAY          0
# PREVAILING_WAGE           0
# PW_UNIT_OF_PAY            0
# PW_WAGE_LEVEL             0
# H-1B_DEPENDENT            0
# dtype: int64

# %% [markdown]
# Filtering the dataset to keep only H-1B visa records

# %%
df = df[df['VISA_CLASS'] == 'H-1B']

# %% [markdown]
# Checking the final shape of the dataset after cleaning and filtering

# %%
df.shape
# Out:
# (453598, 27)

# %% [markdown]
# Saving the cleaned dataset to a CSV file for further analysis or database use

# %%
df.to_csv("h1b_cleaned_data.csv", index=False)
